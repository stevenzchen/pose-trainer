# %%
import os
import sys
import glob
import numpy as np

from parse import load_ps

import matplotlib.pyplot as plt

# %%
def split_num(s):
    head = s.rstrip('0123456789')
    tail = s[len(head):]
    return head, tail

# %%
def files_in_order(folderpath):
    npy_files = os.listdir(folderpath)

    no_extensions = [os.path.splitext(npy_file)[0] for npy_file in npy_files]

    splitted = [split_num(s) for s in no_extensions]

    splitted = np.array(splitted)

    indices = np.lexsort((splitted[:, 1].astype(int), splitted[:, 0]))

    npy_files = np.array(npy_files)
    return npy_files[indices]

# %%
files = files_in_order('poses_compressed\\shoulderpress')
print(files)
# Out:
# ['shoulderpressbad1.npy' 'shoulderpressbad2.npy' 'shoulderpressbad3.npy'
#  'shoulderpressbad4.npy' 'shoulderpressbad5.npy' 'shoulderpressbad6.npy'
#  'shoulderpressbad7.npy' 'shoulderpressbad8.npy' 'shoulderpressbad9.npy'
#  'shoulderpressbad10.npy' 'shoulderpressbad11.npy'
#  'shoulderpressbad12.npy' 'shoulderpressbad13.npy'
#  'shoulderpressbad14.npy' 'shoulderpressbad15.npy'
#  'shoulderpressbad16.npy' 'shoulderpressbad17.npy'
#  'shoulderpressgood1.npy' 'shoulderpressgood2.npy'
#  'shoulderpressgood3.npy' 'shoulderpressgood4.npy'
#  'shoulderpressgood5.npy' 'shoulderpressgood6.npy'
#  'shoulderpressgood7.npy' 'shoulderpressgood8.npy'
#  'shoulderpressgood9.npy' 'shoulderpressgood10.npy'
#  'shoulderpressgood11.npy' 'shoulderpressgood12.npy'
#  'shoulderpressgood13.npy' 'shoulderpressgood14.npy'
#  'shoulderpressgood15.npy' 'shoulderpressgood16.npy'
#  'shoulderpressgood17.npy' 'shoulderpressgood18.npy'
#  'shoulderpressgood19.npy']

# %%
for filename in files:
    print("="*30)
    print("Starting:", filename)
    ps = load_ps("poses_compressed\\shoulderpress\\"+filename)
    poses = ps.poses
    
    right_present = [1 for pose in poses 
            if pose.rshoulder.exists and pose.relbow.exists and pose.rwrist.exists]
    left_present = [1 for pose in poses
            if pose.lshoulder.exists and pose.lelbow.exists and pose.lwrist.exists]
    right_count = sum(right_present)
    left_count = sum(left_present)
    side = 'right' if right_count > left_count else 'left'

    print('Exercise arm detected as: {}.'.format(side))
    
    if side == 'right':
        joints = [(pose.rshoulder, pose.relbow, pose.rwrist, pose.rhip, pose.neck) for pose in poses]
    else:
        joints = [(pose.lshoulder, pose.lelbow, pose.lwrist, pose.lhip, pose.neck) for pose in poses]

    # filter out data points where a part does not exist
    joints = [joint for joint in joints if all(part.exists for part in joint)]
    joints_ = np.array(joints)
    
    # Neck to hip
    back_vec = np.array([(joint[4].x - joint[3].x, joint[4].y - joint[3].y) for joint in joints])
    # Check range of motion of the back
    # Straining back
    back_vec_range = np.max(back_vec, axis=0) - np.min(back_vec, axis=0)
    print("Range of motion for back: %s" % back_vec_range)
    
    # Rolling shoulder too much
    elbow = joints_[:, 1]
    elbow_x = np.array([joint.x for joint in elbow])

    neck = joints_[:, 4]
    neck_x = np.array([joint.x for joint in neck])
        
    if side =='right':
        print("Minimum distance between elbow and neck: ", np.min(elbow_x - neck_x))
    else:
        print("Minimum distance between elbow and neck: ", np.min(neck_x - elbow_x))
    
    # Shoulder to elbow    
    upper_arm_vecs = np.array([(joint[0].x - joint[1].x, joint[0].y - joint[1].y) for joint in joints])
    # Elbow to wrist
    forearm_vecs = np.array([(joint[2].x - joint[1].x, joint[2].y - joint[1].y) for joint in joints])
    
    # normalize vectors
    upper_arm_vecs = upper_arm_vecs / np.expand_dims(np.linalg.norm(upper_arm_vecs, axis=1), axis=1)
    forearm_vecs = forearm_vecs / np.expand_dims(np.linalg.norm(forearm_vecs, axis=1), axis=1)
    
    # Check if raised all the way up
    upper_arm_forearm_angles = np.degrees(np.arccos(np.clip(np.sum(np.multiply(upper_arm_vecs, forearm_vecs), axis=1), -1.0, 1.0)))
    print("Max upper arm and forearm angle: ", np.max(upper_arm_forearm_angles))
    
    plt.scatter(np.arange(back_vec.shape[0]), back_vec[:,0], alpha=0.5)
    plt.title(filename)
    plt.xlabel('Frames')
    plt.ylabel('Back Vector')
    # Set range on y-axis so the plots are consistent
    #plt.ylim(0,90) 
    plt.show()
# Out:
# ==============================
# Starting: shoulderpressbad1.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.18346918 0.06853963]
# Minimum distance between elbow and neck:  -0.022995865846975327
# Max upper arm and forearm angle:  179.7404589175238
# ==============================
# Starting: shoulderpressbad2.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.18327976 0.06885495]
# Minimum distance between elbow and neck:  -0.04603536044865786
# Max upper arm and forearm angle:  179.56518832829843
# ==============================
# Starting: shoulderpressbad3.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.20817404 0.11583217]
# Minimum distance between elbow and neck:  -0.06966123564240245
# Max upper arm and forearm angle:  179.2572660373104
# ==============================
# Starting: shoulderpressbad4.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.20967366 0.10496277]
# Minimum distance between elbow and neck:  -0.057508878609004555
# Max upper arm and forearm angle:  179.64585079957078
# ==============================
# Starting: shoulderpressbad5.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.1723806  0.11400225]
# Minimum distance between elbow and neck:  -0.05664443587544943
# Max upper arm and forearm angle:  162.48917418735942
# ==============================
# Starting: shoulderpressbad6.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.13863649 0.09243432]
# Minimum distance between elbow and neck:  -0.01203015032691157
# Max upper arm and forearm angle:  178.2116989168987
# ==============================
# Starting: shoulderpressbad7.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.16030635 0.10297209]
# Minimum distance between elbow and neck:  -0.057779554519205245
# Max upper arm and forearm angle:  164.15173417668245
# ==============================
# Starting: shoulderpressbad8.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.26382993 0.08044954]
# Minimum distance between elbow and neck:  -0.10405443010956006
# Max upper arm and forearm angle:  178.5053617073325
# ==============================
# Starting: shoulderpressbad9.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.20739249 0.12655405]
# Minimum distance between elbow and neck:  -0.1267337558874373
# Max upper arm and forearm angle:  177.67913765994544
# ==============================
# Starting: shoulderpressbad10.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.20911203 0.12746806]
# Minimum distance between elbow and neck:  -0.16276458331653965
# Max upper arm and forearm angle:  179.72074427153365
# ==============================
# Starting: shoulderpressbad11.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.43907928 0.10048383]
# Minimum distance between elbow and neck:  -0.14983642909352657
# Max upper arm and forearm angle:  169.32345977700024
# ==============================
# Starting: shoulderpressbad12.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.35846499 0.14215479]
# Minimum distance between elbow and neck:  -0.03095705382903846
# Max upper arm and forearm angle:  172.65850140520752
# ==============================
# Starting: shoulderpressbad13.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.08190254 0.0816905 ]
# Minimum distance between elbow and neck:  -0.0706287935739156
# Max upper arm and forearm angle:  179.4984898395085
# ==============================
# Starting: shoulderpressbad14.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.08270467 0.06160164]
# Minimum distance between elbow and neck:  -0.08234005485084284
# Max upper arm and forearm angle:  177.9512031109382
# ==============================
# Starting: shoulderpressbad15.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.25200483 0.10641861]
# Minimum distance between elbow and neck:  -0.2131136955081594
# Max upper arm and forearm angle:  179.92389848131987
# ==============================
# Starting: shoulderpressbad16.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.20284068 0.0870699 ]
# Minimum distance between elbow and neck:  -0.18341213517040167
# Max upper arm and forearm angle:  179.75587386824753
# ==============================
# Starting: shoulderpressbad17.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.07607085 0.09605031]
# Minimum distance between elbow and neck:  -0.1917531426057577
# Max upper arm and forearm angle:  179.38481480593202
# ==============================
# Starting: shoulderpressgood1.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.1194092  0.08679358]
# Minimum distance between elbow and neck:  -0.08609923017958421
# Max upper arm and forearm angle:  179.46269605523918
# ==============================
# Starting: shoulderpressgood2.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.10812673 0.09791107]
# Minimum distance between elbow and neck:  -0.08668320720271305
# Max upper arm and forearm angle:  179.60876198527453
# ==============================
# Starting: shoulderpressgood3.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.1308944  0.07661444]
# Minimum distance between elbow and neck:  -0.10886173347581574
# Max upper arm and forearm angle:  178.468745409546
# ==============================
# Starting: shoulderpressgood4.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.12776206 0.06991002]
# Minimum distance between elbow and neck:  -0.022947408489041976
# Max upper arm and forearm angle:  178.6830755976106
# ==============================
# Starting: shoulderpressgood5.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.13998441 0.09351173]
# Minimum distance between elbow and neck:  -0.023039121538193097
# Max upper arm and forearm angle:  178.6830755976106
# ==============================
# Starting: shoulderpressgood6.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.0827284  0.09273709]
# Minimum distance between elbow and neck:  -0.22237491995938852
# Max upper arm and forearm angle:  179.89944873762423
# ==============================
# Starting: shoulderpressgood7.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.10387269 0.08127466]
# Minimum distance between elbow and neck:  -0.02321989830389315
# Max upper arm and forearm angle:  174.2534220599707
# ==============================
# Starting: shoulderpressgood8.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.12116027 0.06027102]
# Minimum distance between elbow and neck:  -0.011337491056135462
# Max upper arm and forearm angle:  178.76370604621886
# ==============================
# Starting: shoulderpressgood9.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.09802807 0.04899825]
# Minimum distance between elbow and neck:  -0.01175747435495067
# Max upper arm and forearm angle:  179.76786407920594
# ==============================
# Starting: shoulderpressgood10.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.09766109 0.0725993 ]
# Minimum distance between elbow and neck:  0.0007674121916116938
# Max upper arm and forearm angle:  179.97505892293765
# ==============================
# Starting: shoulderpressgood11.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.14612993 0.09685491]
# Minimum distance between elbow and neck:  -0.012129237000912063
# Max upper arm and forearm angle:  179.99392697205886
# ==============================
# Starting: shoulderpressgood12.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.0971625  0.07317682]
# Minimum distance between elbow and neck:  -0.024290625021559542
# Max upper arm and forearm angle:  179.89151109488202
# ==============================
# Starting: shoulderpressgood13.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.16448082 0.13325635]
# Minimum distance between elbow and neck:  -0.051570510286543136
# Max upper arm and forearm angle:  179.90105614933228
# ==============================
# Starting: shoulderpressgood14.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.13566077 0.12499112]
# Minimum distance between elbow and neck:  -0.08302205485445935
# Max upper arm and forearm angle:  179.84130996345874
# ==============================
# Starting: shoulderpressgood15.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.14562496 0.1246373 ]
# Minimum distance between elbow and neck:  -0.08330180151888733
# Max upper arm and forearm angle:  179.82607834431047
# ==============================
# Starting: shoulderpressgood16.npy
# Exercise arm detected as: left.
# Range of motion for back: [0.13699983 0.11601145]
# Minimum distance between elbow and neck:  -0.08470242572590125
# Max upper arm and forearm angle:  179.8182345061486
# ==============================
# Starting: shoulderpressgood17.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.15116277 0.15127741]
# Minimum distance between elbow and neck:  -0.3595069857167512
# Max upper arm and forearm angle:  179.48985845108535
# ==============================
# Starting: shoulderpressgood18.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.15410598 0.13511198]
# Minimum distance between elbow and neck:  -0.36654646344125763
# Max upper arm and forearm angle:  179.85920881961945
# ==============================
# Starting: shoulderpressgood19.npy
# Exercise arm detected as: right.
# Range of motion for back: [0.15392183 0.13495053]
# Minimum distance between elbow and neck:  -0.36610846279703835
# Max upper arm and forearm angle:  179.85920881962204
